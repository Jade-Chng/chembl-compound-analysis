# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load and read csv
df = pd.read_csv('Data_9.csv', delimiter=';')
df
# Out:
#             ChEMBL ID                   Name  \
# 0       CHEMBL3301622           GILTERITINIB
# 1       CHEMBL1614710                OSI-930
# 2          CHEMBL1175             DULOXETINE
# 3            CHEMBL35             FUROSEMIDE
# 4          CHEMBL1433  DOXYCYCLINE ANHYDROUS
# ..                ...                    ...
# 496     CHEMBL4073443           TOMIVOSERTIB
# 497     CHEMBL1997663             ETHACIZINE
# 498     CHEMBL1271993                    NaN
# 499      CHEMBL460491                    NaN
# 500  CHEMBL9993643131              Cisplatin
#
#                                               Synonyms            Type  \
# 0           ASP-2215|ASP2215|GILTERITINIB|Gilteritinib  Small molecule
# 1                                      OSI 930|OSI-930  Small molecule
# 2    Cymbalta|DULOXETINE|Duloxetine|LY-248686|LY248686  Small molecule
# 3    ALUZINE 20|ALUZINE 40|ALUZINE 500|Aquamed|DIUR...  Small molecule
# 4        ANHYDROUS DOXYCYCLINE|DOXYCYCLINE (ANHYDROUS)  Small molecule
# ..                                                 ...             ...
# 496         EFT 508|EFT-508|EFT508|TOMIVOSERTIB|eFT508  Small molecule
# 497  ETACIZIN|ETHACIZIN|ETHACIZINE|ETHACYZIN|ETMOZI...  Small molecule
# 498                                                NaN  Small molecule
# 499                                                NaN  Small molecule
# 500                                                Cis  Small molecule
#
#      Max Phase  Molecular Weight  Targets  Bioactivities  AlogP  \
# 0            4            552.72      297            328   2.70
# 1            1            443.45      304            354   6.06
# 2            4            297.42       49            202   4.63
# 3            4            330.75      216           2809   1.89
# 4            4            444.44      251           2118  -0.35
# ..         ...               ...      ...            ...    ...
# 496          2            340.39       36             89   1.63
# 497          0            413.54       74             82   5.12
# 498          0            361.61       11             28   2.65
# 499          0            406.67       23             67   5.37
# 500          4            284.43      174           2325   4.24
#
#      Polar Surface Area  ...  Inorganic Flag  Heavy Atoms  HBA (Lipinski)  \
# 0                121.11  ...               0           40              11
# 1                 63.25  ...               0           31               5
# 2                 21.26  ...               0           21               2
# 3                122.63  ...               0           21               7
# 4                181.62  ...               0           32              10
# ..                  ...  ...             ...          ...             ...
# 496              114.93  ...               0           25               8
# 497               61.88  ...               0           29               6
# 498               49.85  ...              -1           22               5
# 499               39.99  ...              -1           27               4
# 500                6.48  ...               0           20               2
#
#      HBD (Lipinski) #RO5 Violations (Lipinski)  \
# 0                 4                          2
# 1                 2                          1
# 2                 1                          0
# 3                 4                          0
# 4                 7                          1
# ..              ...                        ...
# 496               4                          0
# 497               1                          1
# 498               0                          0
# 499               1                          1
# 500               0                          0
#
#      Molecular Weight (Monoisotopic)  Molecular Species  Molecular Formula  \
# 0                           552.3536            NEUTRAL         C29H44N8O3
# 1                           443.0915            NEUTRAL      C22H16F3N3O2S
# 2                           297.1187               BASE          C18H19NOS
# 3                           330.0077               ACID      C12H11ClN2O5S
# 4                           444.1533               ACID         C22H24N2O8
# ..                               ...                ...                ...
# 496                         340.1648            NEUTRAL         C17H20N6O2
# 497                         413.1773               BASE        C22H27N3O3S
# 498                         359.9835            NEUTRAL      C14H11Cl3N2O3
# 499                         406.2225               BASE         C21H34N4S2
# 500                         284.1347               BASE          C17H20N2S
#
#                                                 Smiles  \
# 0    CCc1nc(C(N)=O)c(Nc2ccc(N3CCC(N4CCN(C)CC4)CC3)c...
# 1     O=C(Nc1ccc(OC(F)(F)F)cc1)c1sccc1NCc1ccnc2ccccc12
# 2                    CNCC[C@H](Oc1cccc2ccccc12)c1cccs1
# 3              NS(=O)(=O)c1cc(C(=O)O)c(NCc2ccco2)cc1Cl
# 4    C[C@H]1c2cccc(O)c2C(=O)C2=C(O)[C@]3(O)C(=O)C(C...
# ..                                                 ...
# 496        Cc1cc(Nc2cc(N)ncn2)c(=O)n2c1C(=O)NC21CCCCC1
# 497    CCOC(=O)Nc1ccc2c(c1)N(C(=O)CCN(CC)CC)c1ccccc1S2
# 498       O=C1C(Cl)=C(N2CCOCC2)C(=O)N1c1ccc(Cl)c(Cl)c1
# 499     CC1(C)CN2C(CS/C(=N\C3CCCCC3)NC3CCCCC3)=CSC2=N1
# 500                     CC(CN1c2ccccc2Sc2ccccc21)N(C)C
#
#                        Inchi Key
# 0    GYQYAJJFPNQOOW-UHFFFAOYSA-N
# 1    FGTCROZDHDSNIO-UHFFFAOYSA-N
# 2    ZEUITGRIYCTCEM-KRWDZBQOSA-N
# 3    ZZUFCTLCJUWOSV-UHFFFAOYSA-N
# 4    JBIWCJUYHHGXTC-AKNGSSGZSA-N
# ..                           ...
# 496  HKTBYUWLRDZAJK-UHFFFAOYSA-N
# 497  PQXGNJKJMFUPPM-UHFFFAOYSA-N
# 498  MWSUIZKGNWELRF-UHFFFAOYSA-N
# 499  OOSUDWRRWZVFEB-UHFFFAOYSA-N
# 500  PWWVAXIEGOYWEE-UHFFFAOYSA-N
#
# [501 rows x 32 columns]

# %%
act = pd.read_csv('Activity.csv', delimiter=';')
act
# Out:
#           ChEMBL ID  IC50 value IC50 unit
# 0      CHEMBL590799       160.0        nM
# 1      CHEMBL214253      3170.0        nM
# 2     CHEMBL1200675      4580.0        nM
# 3      CHEMBL258405       750.0        nM
# 4      CHEMBL474133     10000.0        nM
# ...             ...         ...       ...
# 7995   CHEMBL225411       110.0        nM
# 7996      CHEMBL686      9940.0        nM
# 7997      CHEMBL483     33000.0        nM
# 7998      CHEMBL590     33000.0        nM
# 7999   CHEMBL191413     15680.0        nM
#
# [8000 rows x 3 columns]

# %%
#Merge
mydf = pd.merge(df, act, on='ChEMBL ID')
mydf
# Out:
#          ChEMBL ID                   Name  \
# 0    CHEMBL3301622           GILTERITINIB
# 1    CHEMBL1614710                OSI-930
# 2       CHEMBL1175             DULOXETINE
# 3         CHEMBL35             FUROSEMIDE
# 4       CHEMBL1433  DOXYCYCLINE ANHYDROUS
# ..             ...                    ...
# 495  CHEMBL3337894                  T-26c
# 496  CHEMBL4073443           TOMIVOSERTIB
# 497  CHEMBL1997663             ETHACIZINE
# 498  CHEMBL1271993                    NaN
# 499   CHEMBL460491                    NaN
#
#                                               Synonyms            Type  \
# 0           ASP-2215|ASP2215|GILTERITINIB|Gilteritinib  Small molecule
# 1                                      OSI 930|OSI-930  Small molecule
# 2    Cymbalta|DULOXETINE|Duloxetine|LY-248686|LY248686  Small molecule
# 3    ALUZINE 20|ALUZINE 40|ALUZINE 500|Aquamed|DIUR...  Small molecule
# 4        ANHYDROUS DOXYCYCLINE|DOXYCYCLINE (ANHYDROUS)  Small molecule
# ..                                                 ...             ...
# 495                                                NaN  Small molecule
# 496         EFT 508|EFT-508|EFT508|TOMIVOSERTIB|eFT508  Small molecule
# 497  ETACIZIN|ETHACIZIN|ETHACIZINE|ETHACYZIN|ETMOZI...  Small molecule
# 498                                                NaN  Small molecule
# 499                                                NaN  Small molecule
#
#      Max Phase  Molecular Weight  Targets  Bioactivities  AlogP  \
# 0            4            552.72      297            328   2.70
# 1            1            443.45      304            354   6.06
# 2            4            297.42       49            202   4.63
# 3            4            330.75      216           2809   1.89
# 4            4            444.44      251           2118  -0.35
# ..         ...               ...      ...            ...    ...
# 495          0            479.51      459            589   3.34
# 496          2            340.39       36             89   1.63
# 497          0            413.54       74             82   5.12
# 498          0            361.61       11             28   2.65
# 499          0            406.67       23             67   5.37
#
#      Polar Surface Area  ...  HBA (Lipinski)  HBD (Lipinski)  \
# 0                121.11  ...              11               4
# 1                 63.25  ...               5               2
# 2                 21.26  ...               2               1
# 3                122.63  ...               7               4
# 4                181.62  ...              10               7
# ..                  ...  ...             ...             ...
# 495              130.61  ...               9               3
# 496              114.93  ...               8               4
# 497               61.88  ...               6               1
# 498               49.85  ...               5               0
# 499               39.99  ...               4               1
#
#      #RO5 Violations (Lipinski)  Molecular Weight (Monoisotopic)  \
# 0                             2                         552.3536
# 1                             1                         443.0915
# 2                             0                         297.1187
# 3                             0                         330.0077
# 4                             1                         444.1533
# ..                          ...                              ...
# 495                           0                         479.1151
# 496                           0                         340.1648
# 497                           1                         413.1773
# 498                           0                         359.9835
# 499                           1                         406.2225
#
#     Molecular Species  Molecular Formula  \
# 0             NEUTRAL         C29H44N8O3
# 1             NEUTRAL      C22H16F3N3O2S
# 2                BASE          C18H19NOS
# 3                ACID      C12H11ClN2O5S
# 4                ACID         C22H24N2O8
# ..                ...                ...
# 495              ACID        C24H21N3O6S
# 496           NEUTRAL         C17H20N6O2
# 497              BASE        C22H27N3O3S
# 498           NEUTRAL      C14H11Cl3N2O3
# 499              BASE         C21H34N4S2
#
#                                                 Smiles  \
# 0    CCc1nc(C(N)=O)c(Nc2ccc(N3CCC(N4CCN(C)CC4)CC3)c...
# 1     O=C(Nc1ccc(OC(F)(F)F)cc1)c1sccc1NCc1ccnc2ccccc12
# 2                    CNCC[C@H](Oc1cccc2ccccc12)c1cccs1
# 3              NS(=O)(=O)c1cc(C(=O)O)c(NCc2ccco2)cc1Cl
# 4    C[C@H]1c2cccc(O)c2C(=O)C2=C(O)[C@]3(O)C(=O)C(C...
# ..                                                 ...
# 495  COc1cccc(CNC(=O)c2nc3scc(COCc4ccc(C(=O)O)cc4)c...
# 496        Cc1cc(Nc2cc(N)ncn2)c(=O)n2c1C(=O)NC21CCCCC1
# 497    CCOC(=O)Nc1ccc2c(c1)N(C(=O)CCN(CC)CC)c1ccccc1S2
# 498       O=C1C(Cl)=C(N2CCOCC2)C(=O)N1c1ccc(Cl)c(Cl)c1
# 499     CC1(C)CN2C(CS/C(=N\C3CCCCC3)NC3CCCCC3)=CSC2=N1
#
#                        Inchi Key  IC50 value  IC50 unit
# 0    GYQYAJJFPNQOOW-UHFFFAOYSA-N    4341.008         nM
# 1    FGTCROZDHDSNIO-UHFFFAOYSA-N   13986.462         nM
# 2    ZEUITGRIYCTCEM-KRWDZBQOSA-N   34883.100         nM
# 3    ZZUFCTLCJUWOSV-UHFFFAOYSA-N   10575.670         nM
# 4    JBIWCJUYHHGXTC-AKNGSSGZSA-N      11.074         nM
# ..                           ...         ...        ...
# 495  CDQRIIUMNLMHRH-UHFFFAOYSA-N     431.886         nM
# 496  HKTBYUWLRDZAJK-UHFFFAOYSA-N     819.476         nM
# 497  PQXGNJKJMFUPPM-UHFFFAOYSA-N   12890.136         nM
# 498  MWSUIZKGNWELRF-UHFFFAOYSA-N    4119.528         nM
# 499  OOSUDWRRWZVFEB-UHFFFAOYSA-N     365.442         nM
#
# [500 rows x 34 columns]

# %%
#Standardise
mydf['Standard'] = np.where(mydf['IC50 unit']=="nm", mydf['IC50 value']*1e-9, mydf['IC50 value']*1e-6)
mydf
# Out:
#          ChEMBL ID                   Name  \
# 0    CHEMBL3301622           GILTERITINIB
# 1    CHEMBL1614710                OSI-930
# 2       CHEMBL1175             DULOXETINE
# 3         CHEMBL35             FUROSEMIDE
# 4       CHEMBL1433  DOXYCYCLINE ANHYDROUS
# ..             ...                    ...
# 495  CHEMBL3337894                  T-26c
# 496  CHEMBL4073443           TOMIVOSERTIB
# 497  CHEMBL1997663             ETHACIZINE
# 498  CHEMBL1271993                    NaN
# 499   CHEMBL460491                    NaN
#
#                                               Synonyms            Type  \
# 0           ASP-2215|ASP2215|GILTERITINIB|Gilteritinib  Small molecule
# 1                                      OSI 930|OSI-930  Small molecule
# 2    Cymbalta|DULOXETINE|Duloxetine|LY-248686|LY248686  Small molecule
# 3    ALUZINE 20|ALUZINE 40|ALUZINE 500|Aquamed|DIUR...  Small molecule
# 4        ANHYDROUS DOXYCYCLINE|DOXYCYCLINE (ANHYDROUS)  Small molecule
# ..                                                 ...             ...
# 495                                                NaN  Small molecule
# 496         EFT 508|EFT-508|EFT508|TOMIVOSERTIB|eFT508  Small molecule
# 497  ETACIZIN|ETHACIZIN|ETHACIZINE|ETHACYZIN|ETMOZI...  Small molecule
# 498                                                NaN  Small molecule
# 499                                                NaN  Small molecule
#
#      Max Phase  Molecular Weight  Targets  Bioactivities  AlogP  \
# 0            4            552.72      297            328   2.70
# 1            1            443.45      304            354   6.06
# 2            4            297.42       49            202   4.63
# 3            4            330.75      216           2809   1.89
# 4            4            444.44      251           2118  -0.35
# ..         ...               ...      ...            ...    ...
# 495          0            479.51      459            589   3.34
# 496          2            340.39       36             89   1.63
# 497          0            413.54       74             82   5.12
# 498          0            361.61       11             28   2.65
# 499          0            406.67       23             67   5.37
#
#      Polar Surface Area  ...  HBD (Lipinski)  #RO5 Violations (Lipinski)  \
# 0                121.11  ...               4                           2
# 1                 63.25  ...               2                           1
# 2                 21.26  ...               1                           0
# 3                122.63  ...               4                           0
# 4                181.62  ...               7                           1
# ..                  ...  ...             ...                         ...
# 495              130.61  ...               3                           0
# 496              114.93  ...               4                           0
# 497               61.88  ...               1                           1
# 498               49.85  ...               0                           0
# 499               39.99  ...               1                           1
#
#      Molecular Weight (Monoisotopic)  Molecular Species Molecular Formula  \
# 0                           552.3536            NEUTRAL        C29H44N8O3
# 1                           443.0915            NEUTRAL     C22H16F3N3O2S
# 2                           297.1187               BASE         C18H19NOS
# 3                           330.0077               ACID     C12H11ClN2O5S
# 4                           444.1533               ACID        C22H24N2O8
# ..                               ...                ...               ...
# 495                         479.1151               ACID       C24H21N3O6S
# 496                         340.1648            NEUTRAL        C17H20N6O2
# 497                         413.1773               BASE       C22H27N3O3S
# 498                         359.9835            NEUTRAL     C14H11Cl3N2O3
# 499                         406.2225               BASE        C21H34N4S2
#
#                                                 Smiles  \
# 0    CCc1nc(C(N)=O)c(Nc2ccc(N3CCC(N4CCN(C)CC4)CC3)c...
# 1     O=C(Nc1ccc(OC(F)(F)F)cc1)c1sccc1NCc1ccnc2ccccc12
# 2                    CNCC[C@H](Oc1cccc2ccccc12)c1cccs1
# 3              NS(=O)(=O)c1cc(C(=O)O)c(NCc2ccco2)cc1Cl
# 4    C[C@H]1c2cccc(O)c2C(=O)C2=C(O)[C@]3(O)C(=O)C(C...
# ..                                                 ...
# 495  COc1cccc(CNC(=O)c2nc3scc(COCc4ccc(C(=O)O)cc4)c...
# 496        Cc1cc(Nc2cc(N)ncn2)c(=O)n2c1C(=O)NC21CCCCC1
# 497    CCOC(=O)Nc1ccc2c(c1)N(C(=O)CCN(CC)CC)c1ccccc1S2
# 498       O=C1C(Cl)=C(N2CCOCC2)C(=O)N1c1ccc(Cl)c(Cl)c1
# 499     CC1(C)CN2C(CS/C(=N\C3CCCCC3)NC3CCCCC3)=CSC2=N1
#
#                        Inchi Key  IC50 value  IC50 unit  Standard
# 0    GYQYAJJFPNQOOW-UHFFFAOYSA-N    4341.008         nM  0.004341
# 1    FGTCROZDHDSNIO-UHFFFAOYSA-N   13986.462         nM  0.013986
# 2    ZEUITGRIYCTCEM-KRWDZBQOSA-N   34883.100         nM  0.034883
# 3    ZZUFCTLCJUWOSV-UHFFFAOYSA-N   10575.670         nM  0.010576
# 4    JBIWCJUYHHGXTC-AKNGSSGZSA-N      11.074         nM  0.000011
# ..                           ...         ...        ...       ...
# 495  CDQRIIUMNLMHRH-UHFFFAOYSA-N     431.886         nM  0.000432
# 496  HKTBYUWLRDZAJK-UHFFFAOYSA-N     819.476         nM  0.000819
# 497  PQXGNJKJMFUPPM-UHFFFAOYSA-N   12890.136         nM  0.012890
# 498  MWSUIZKGNWELRF-UHFFFAOYSA-N    4119.528         nM  0.004120
# 499  OOSUDWRRWZVFEB-UHFFFAOYSA-N     365.442         nM  0.000365
#
# [500 rows x 35 columns]

# %%
#Convert to pIC50
mydf['pIC50'] = -np.log10(mydf['Standard'])
mydf
# Out:
#          ChEMBL ID                   Name  \
# 0    CHEMBL3301622           GILTERITINIB
# 1    CHEMBL1614710                OSI-930
# 2       CHEMBL1175             DULOXETINE
# 3         CHEMBL35             FUROSEMIDE
# 4       CHEMBL1433  DOXYCYCLINE ANHYDROUS
# ..             ...                    ...
# 495  CHEMBL3337894                  T-26c
# 496  CHEMBL4073443           TOMIVOSERTIB
# 497  CHEMBL1997663             ETHACIZINE
# 498  CHEMBL1271993                    NaN
# 499   CHEMBL460491                    NaN
#
#                                               Synonyms            Type  \
# 0           ASP-2215|ASP2215|GILTERITINIB|Gilteritinib  Small molecule
# 1                                      OSI 930|OSI-930  Small molecule
# 2    Cymbalta|DULOXETINE|Duloxetine|LY-248686|LY248686  Small molecule
# 3    ALUZINE 20|ALUZINE 40|ALUZINE 500|Aquamed|DIUR...  Small molecule
# 4        ANHYDROUS DOXYCYCLINE|DOXYCYCLINE (ANHYDROUS)  Small molecule
# ..                                                 ...             ...
# 495                                                NaN  Small molecule
# 496         EFT 508|EFT-508|EFT508|TOMIVOSERTIB|eFT508  Small molecule
# 497  ETACIZIN|ETHACIZIN|ETHACIZINE|ETHACYZIN|ETMOZI...  Small molecule
# 498                                                NaN  Small molecule
# 499                                                NaN  Small molecule
#
#      Max Phase  Molecular Weight  Targets  Bioactivities  AlogP  \
# 0            4            552.72      297            328   2.70
# 1            1            443.45      304            354   6.06
# 2            4            297.42       49            202   4.63
# 3            4            330.75      216           2809   1.89
# 4            4            444.44      251           2118  -0.35
# ..         ...               ...      ...            ...    ...
# 495          0            479.51      459            589   3.34
# 496          2            340.39       36             89   1.63
# 497          0            413.54       74             82   5.12
# 498          0            361.61       11             28   2.65
# 499          0            406.67       23             67   5.37
#
#      Polar Surface Area  ...  #RO5 Violations (Lipinski)  \
# 0                121.11  ...                           2
# 1                 63.25  ...                           1
# 2                 21.26  ...                           0
# 3                122.63  ...                           0
# 4                181.62  ...                           1
# ..                  ...  ...                         ...
# 495              130.61  ...                           0
# 496              114.93  ...                           0
# 497               61.88  ...                           1
# 498               49.85  ...                           0
# 499               39.99  ...                           1
#
#      Molecular Weight (Monoisotopic)  Molecular Species  Molecular Formula  \
# 0                           552.3536            NEUTRAL         C29H44N8O3
# 1                           443.0915            NEUTRAL      C22H16F3N3O2S
# 2                           297.1187               BASE          C18H19NOS
# 3                           330.0077               ACID      C12H11ClN2O5S
# 4                           444.1533               ACID         C22H24N2O8
# ..                               ...                ...                ...
# 495                         479.1151               ACID        C24H21N3O6S
# 496                         340.1648            NEUTRAL         C17H20N6O2
# 497                         413.1773               BASE        C22H27N3O3S
# 498                         359.9835            NEUTRAL      C14H11Cl3N2O3
# 499                         406.2225               BASE         C21H34N4S2
#
#                                                 Smiles  \
# 0    CCc1nc(C(N)=O)c(Nc2ccc(N3CCC(N4CCN(C)CC4)CC3)c...
# 1     O=C(Nc1ccc(OC(F)(F)F)cc1)c1sccc1NCc1ccnc2ccccc12
# 2                    CNCC[C@H](Oc1cccc2ccccc12)c1cccs1
# 3              NS(=O)(=O)c1cc(C(=O)O)c(NCc2ccco2)cc1Cl
# 4    C[C@H]1c2cccc(O)c2C(=O)C2=C(O)[C@]3(O)C(=O)C(C...
# ..                                                 ...
# 495  COc1cccc(CNC(=O)c2nc3scc(COCc4ccc(C(=O)O)cc4)c...
# 496        Cc1cc(Nc2cc(N)ncn2)c(=O)n2c1C(=O)NC21CCCCC1
# 497    CCOC(=O)Nc1ccc2c(c1)N(C(=O)CCN(CC)CC)c1ccccc1S2
# 498       O=C1C(Cl)=C(N2CCOCC2)C(=O)N1c1ccc(Cl)c(Cl)c1
# 499     CC1(C)CN2C(CS/C(=N\C3CCCCC3)NC3CCCCC3)=CSC2=N1
#
#                        Inchi Key  IC50 value  IC50 unit  Standard     pIC50
# 0    GYQYAJJFPNQOOW-UHFFFAOYSA-N    4341.008         nM  0.004341  2.362409
# 1    FGTCROZDHDSNIO-UHFFFAOYSA-N   13986.462         nM  0.013986  1.854292
# 2    ZEUITGRIYCTCEM-KRWDZBQOSA-N   34883.100         nM  0.034883  1.457385
# 3    ZZUFCTLCJUWOSV-UHFFFAOYSA-N   10575.670         nM  0.010576  1.975692
# 4    JBIWCJUYHHGXTC-AKNGSSGZSA-N      11.074         nM  0.000011  4.955695
# ..                           ...         ...        ...       ...       ...
# 495  CDQRIIUMNLMHRH-UHFFFAOYSA-N     431.886         nM  0.000432  3.364631
# 496  HKTBYUWLRDZAJK-UHFFFAOYSA-N     819.476         nM  0.000819  3.086464
# 497  PQXGNJKJMFUPPM-UHFFFAOYSA-N   12890.136         nM  0.012890  1.889743
# 498  MWSUIZKGNWELRF-UHFFFAOYSA-N    4119.528         nM  0.004120  2.385153
# 499  OOSUDWRRWZVFEB-UHFFFAOYSA-N     365.442         nM  0.000365  3.437182
#
# [500 rows x 36 columns]

# %%
#Data cleaning
mydf = mydf.dropna(subset = ['Name'])
mydf
# Out:
#          ChEMBL ID                   Name  \
# 0    CHEMBL3301622           GILTERITINIB
# 1    CHEMBL1614710                OSI-930
# 2       CHEMBL1175             DULOXETINE
# 3         CHEMBL35             FUROSEMIDE
# 4       CHEMBL1433  DOXYCYCLINE ANHYDROUS
# ..             ...                    ...
# 492  CHEMBL2103954             EMORFAZONE
# 493    CHEMBL17331              PD-169316
# 495  CHEMBL3337894                  T-26c
# 496  CHEMBL4073443           TOMIVOSERTIB
# 497  CHEMBL1997663             ETHACIZINE
#
#                                               Synonyms            Type  \
# 0           ASP-2215|ASP2215|GILTERITINIB|Gilteritinib  Small molecule
# 1                                      OSI 930|OSI-930  Small molecule
# 2    Cymbalta|DULOXETINE|Duloxetine|LY-248686|LY248686  Small molecule
# 3    ALUZINE 20|ALUZINE 40|ALUZINE 500|Aquamed|DIUR...  Small molecule
# 4        ANHYDROUS DOXYCYCLINE|DOXYCYCLINE (ANHYDROUS)  Small molecule
# ..                                                 ...             ...
# 492                                 EMORFAZONE|PENTOIL  Small molecule
# 493                                          PD-169316  Small molecule
# 495                                                NaN  Small molecule
# 496         EFT 508|EFT-508|EFT508|TOMIVOSERTIB|eFT508  Small molecule
# 497  ETACIZIN|ETHACIZIN|ETHACIZINE|ETHACYZIN|ETMOZI...  Small molecule
#
#      Max Phase  Molecular Weight  Targets  Bioactivities  AlogP  \
# 0            4            552.72      297            328   2.70
# 1            1            443.45      304            354   6.06
# 2            4            297.42       49            202   4.63
# 3            4            330.75      216           2809   1.89
# 4            4            444.44      251           2118  -0.35
# ..         ...               ...      ...            ...    ...
# 492          0            239.27        6             19   0.02
# 493          0            360.35      300            618   4.85
# 495          0            479.51      459            589   3.34
# 496          2            340.39       36             89   1.63
# 497          0            413.54       74             82   5.12
#
#      Polar Surface Area  ...  #RO5 Violations (Lipinski)  \
# 0                121.11  ...                           2
# 1                 63.25  ...                           1
# 2                 21.26  ...                           0
# 3                122.63  ...                           0
# 4                181.62  ...                           1
# ..                  ...  ...                         ...
# 492               56.59  ...                           0
# 493               84.71  ...                           0
# 495              130.61  ...                           0
# 496              114.93  ...                           0
# 497               61.88  ...                           1
#
#      Molecular Weight (Monoisotopic)  Molecular Species  Molecular Formula  \
# 0                           552.3536            NEUTRAL         C29H44N8O3
# 1                           443.0915            NEUTRAL      C22H16F3N3O2S
# 2                           297.1187               BASE          C18H19NOS
# 3                           330.0077               ACID      C12H11ClN2O5S
# 4                           444.1533               ACID         C22H24N2O8
# ..                               ...                ...                ...
# 492                         239.1270            NEUTRAL         C11H17N3O3
# 493                         360.1023            NEUTRAL        C20H13FN4O2
# 495                         479.1151               ACID        C24H21N3O6S
# 496                         340.1648            NEUTRAL         C17H20N6O2
# 497                         413.1773               BASE        C22H27N3O3S
#
#                                                 Smiles  \
# 0    CCc1nc(C(N)=O)c(Nc2ccc(N3CCC(N4CCN(C)CC4)CC3)c...
# 1     O=C(Nc1ccc(OC(F)(F)F)cc1)c1sccc1NCc1ccnc2ccccc12
# 2                    CNCC[C@H](Oc1cccc2ccccc12)c1cccs1
# 3              NS(=O)(=O)c1cc(C(=O)O)c(NCc2ccco2)cc1Cl
# 4    C[C@H]1c2cccc(O)c2C(=O)C2=C(O)[C@]3(O)C(=O)C(C...
# ..                                                 ...
# 492                         CCOc1c(N2CCOCC2)cnn(C)c1=O
# 493  O=[N+]([O-])c1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccnc...
# 495  COc1cccc(CNC(=O)c2nc3scc(COCc4ccc(C(=O)O)cc4)c...
# 496        Cc1cc(Nc2cc(N)ncn2)c(=O)n2c1C(=O)NC21CCCCC1
# 497    CCOC(=O)Nc1ccc2c(c1)N(C(=O)CCN(CC)CC)c1ccccc1S2
#
#                        Inchi Key  IC50 value  IC50 unit  Standard     pIC50
# 0    GYQYAJJFPNQOOW-UHFFFAOYSA-N    4341.008         nM  0.004341  2.362409
# 1    FGTCROZDHDSNIO-UHFFFAOYSA-N   13986.462         nM  0.013986  1.854292
# 2    ZEUITGRIYCTCEM-KRWDZBQOSA-N   34883.100         nM  0.034883  1.457385
# 3    ZZUFCTLCJUWOSV-UHFFFAOYSA-N   10575.670         nM  0.010576  1.975692
# 4    JBIWCJUYHHGXTC-AKNGSSGZSA-N      11.074         nM  0.000011  4.955695
# ..                           ...         ...        ...       ...       ...
# 492  URJQOOISAKEBKW-UHFFFAOYSA-N     476.182         nM  0.000476  3.322227
# 493  BGIYKDUASORTBB-UHFFFAOYSA-N     221.480         nM  0.000221  3.654665
# 495  CDQRIIUMNLMHRH-UHFFFAOYSA-N     431.886         nM  0.000432  3.364631
# 496  HKTBYUWLRDZAJK-UHFFFAOYSA-N     819.476         nM  0.000819  3.086464
# 497  PQXGNJKJMFUPPM-UHFFFAOYSA-N   12890.136         nM  0.012890  1.889743
#
# [362 rows x 36 columns]

# %% [markdown]
# ##My Answer

# %%
#1. Based on their pIC50 values, what are the names of the least active and most active compounds? Print your output in complete sentences.
mydf.loc[mydf['pIC50'].idxmin(), 'Name']
# Out:
# 'CRIZOTINIB'

# %%
mydf.loc[mydf['pIC50'].idxmax(), 'Name']
# Out:
# 'TARANABANT'

# %%
#Print in a full sentence
print(f"The least active compound is {mydf.loc[mydf['pIC50'].idxmin(), 'Name']} and the most active compound is {mydf.loc[mydf['pIC50'].idxmax(), 'Name']}.")
# Out:
# The least active compound is CRIZOTINIB and the most active compound is TARANABANT.

# %%
#2. What is the median Polar Surface Area? Print your output in a complete sentence.
np.median(mydf['Polar Surface Area'])
print(f"The median Polar Surface Area is {np.median(mydf['Polar Surface Area'])}.")
# Out:
# The median Polar Surface Area is 71.965.

# %%
#3. The compounds in this dataset belong to different Molecular Species. How many compounds are labelled as 'ACID'? Print your output in a complete sentence.
mydf['Molecular Species'].value_counts()['ACID']
print(f"There are {mydf['Molecular Species'].value_counts()['ACID']} compounds labelled as 'ACID'.")
# Out:
# There are 78 compounds labelled as 'ACID'.

# %%
#4. What is the number of compounds with molecular weights more than 180 and less than 400 g/mol? Print your output in a complete sentence.
mydf[(mydf['Molecular Weight'] > 180) & (mydf['Molecular Weight'] < 400)].shape[0]
print(f"There are {mydf[(mydf['Molecular Weight'] > 180) & (mydf['Molecular Weight'] < 400)].shape[0]} compounds with molecular weights more than 180 and less than 400 g/mol.")
# Out:
# There are 215 compounds with molecular weights more than 180 and less than 400 g/mol.

# %%
#5. What is the mean and standard deviation of the pIC50 value of the compounds in your dataframe? Print your output in a complete sentence.
mydf['pIC50'].mean()
mydf['pIC50'].std()
print(f"The mean of the pIC50 value is {mydf['pIC50'].mean()} and the standard deviation is {mydf['pIC50'].std()}.")
# Out:
# The mean of the pIC50 value is 2.3068229274681142 and the standard deviation is 0.9727833370918881.

# %%
#6. What are the first, second and third quartiles of the ‘Bioactivities’ values?
mydf['Bioactivities'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     46.0
# 0.50    122.5
# 0.75    453.5
# Name: Bioactivities, dtype: float64

# %%
#7. Build one line of code to find the number of compounds for each #RO5 Violations.
mydf['#RO5 Violations'].value_counts()
# Out:
# #RO5 Violations
# 0    276
# 1     51
# 2     30
# 3      5
# Name: count, dtype: int64

# %%
#8. How many compounds meet the criteria of HBA and HBD less than or equal to 3? Print your answer in a full sentence.
mydf[(mydf['HBA'] <= 3) & (mydf['HBD'] <= 3)].shape[0]
print(f"There are {mydf[(mydf['HBA'] <= 3) & (mydf['HBD'] <= 3)].shape[0]} compounds meet the criteria of HBA and HBD less than or equal to 3.")
# Out:
# There are 136 compounds meet the criteria of HBA and HBD less than or equal to 3.

# %%
#9. What is the statistical summary of the ‘Aromatic Rings’ from the dataset?
mydf['Aromatic Rings'].describe()
# Out:
# count    362.000000
# mean       1.781768
# std        1.273814
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        6.000000
# Name: Aromatic Rings, dtype: float64

# %%
#10. Find the minimum and maximum values for both AlogP and CX LogP. Print the output in complete sentences.
mydf[['AlogP', 'CX LogP']].agg(['min', 'max'])
# Out:
#      AlogP  CX LogP
# min  -5.40    -7.72
# max   9.01    10.01

# %%
print(f"The minimum value for AlogP and CX LogP are {mydf['AlogP'].min()} and {mydf['CX LogP'].min()}, while the maximum value for AlogP and CX LogP are {mydf['AlogP'].max()} and {mydf['CX LogP'].max()} respectively.")
# Out:
# The minimum value for AlogP and CX LogP are -5.4 and -7.72, while the maximum value for AlogP and CX LogP are 9.01 and 10.01 respectively.

# %%
#11. Filter your dataframe to keep data rows that meet these two requirements: i) Zero rule of 5 Violations (#RO5 Violations), and ii) pIC50 more than 5.0.
filtered = mydf[(mydf['#RO5 Violations'] == 0) & (mydf['pIC50'] > 5.0)]

# %%
filtered
# Out:
#       ChEMBL ID                       Name  \
# 172  CHEMBL1671  PROPRANOLOL HYDROCHLORIDE
#
#                                               Synonyms            Type  \
# 172  ANGILOL|APSOLOL|AVLOCARDYL|AY 64043|AY-64043|B...  Small molecule
#
#      Max Phase  Molecular Weight  Targets  Bioactivities  AlogP  \
# 172          4            295.81       46            127   2.58
#
#      Polar Surface Area  ...  #RO5 Violations (Lipinski)  \
# 172               41.49  ...                           0
#
#      Molecular Weight (Monoisotopic)  Molecular Species  Molecular Formula  \
# 172                         259.1572               BASE        C16H22ClNO2
#
#                              Smiles                    Inchi Key  IC50 value  \
# 172  CC(C)NCC(O)COc1cccc2ccccc12.Cl  ZMRUPTIKESYGQW-UHFFFAOYSA-N    7.367532
#
#      IC50 unit  Standard     pIC50
# 172         nM  0.000007  5.132678
#
# [1 rows x 36 columns]

# %%
#12. Plot a category plot to depict the pIC50 (y-axis) values based on the Molecular species (x-axis). The type of category plot should be boxen. Add a suitable title.
sns.catplot(data = mydf,
            x = 'Molecular Species',
            y = 'pIC50',
            kind = 'boxen')

plt.title('pIC50 values based on the Molecular species')
plt.show()

# %%
#13. Plot a set of pair-wise scatter plots to depict the relationship for HBA, HBD, AlogP, Polar Surface Area and Inorganic Flags. The diagonal plot should be in kernel density estimate (kde). The plot’s variable (hue) should be differentiated by the #RO5 Violations. KDE plots should be applied to lower triangle plots. Choose a suitable colour palette.
num_cols = ["HBA", "HBD", "AlogP", "Polar Surface Area", "Inorganic Flag", "#RO5 Violations"]

sns.pairplot(mydf[num_cols],
             vars = ['HBA', 'HBD', 'AlogP', 'Polar Surface Area', 'Inorganic Flag'],
             diag_kind= 'kde',
             hue='#RO5 Violations',
             palette="Set2"
             ).map_lower(sns.kdeplot, cmap="Blues_d")

plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:1128: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)

# %%
#14. Create a jointplot to visualise the Molecular weight (y-axis) vs the AlogP (x-axis). The datapoints should be visualised using hexagonal bins. Add the x- and y-axis labels.
sns.jointplot(data = mydf,
              x = 'AlogP',
              y = 'Molecular Weight',
              kind = 'hex')

plt.xlabel('AlogP')
plt.ylabel('Molecular Weight')
plt.show()

# %%
#15. Plot a histogram to show the frequency of the pIC50 values. The histogram should have 25 bins. Annotate the histogram with lines to represent the mean, median, minimum and maximum pIC50. Add a suitable title and the legends.
fig, ax = plt.subplots()

plt.hist(mydf['pIC50'],
         bins = 25,
         edgecolor = 'black',
         )

ax.set_xlabel('pIC50')
ax.set_ylabel('Frequency')
ax.set_title('Frequency of the pIC50 values')

mean = np.mean(mydf['pIC50'])
median = np.median(mydf['pIC50'])

ax.axvline (x = mean, color = 'r', label = 'Mean', linestyle = '-', linewidth = 1.5)
ax.axvline (x = median, color = 'r', label = 'Median', linestyle = '--', linewidth = 1.5)

ax.legend()
